# %% [markdown]
# # Chapter 5 : Data Visualization

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# One-dimensional data set
np.random.seed(1000)
y = np.random.standard_normal(20)
x = range(len(y))
plt.plot(x, y)

# %%
# since y is an ndarray object we can simply do
plt.plot(y)

# %%
# cumulative sum of the data
plt.plot(y.cumsum())

# with a grid and adjusted axis
plt.grid(True)
plt.axis('tight')
# Out:
# (0.0, 19.0, -2.1915310617211072, 0.43422097883764876)

# %%
# cumulative sum of the data
plt.plot(y.cumsum())

# with a grid and limited axis
plt.grid(True)
plt.xlim(-1, 20)
plt.ylim(np.min(y.cumsum()) - 1,
         np.max(y.cumsum()) + 1)
# Out:
# (-3.1915310617211072, 1.4342209788376488)

# %%
# cumulative sum of the data
plt.figure(figsize=(7, 4))

# with a grid, adjusted axis and colors
plt.plot(y.cumsum(), 'b', lw=1.5)
plt.plot(y.cumsum(), 'ro')
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A simple plot')

# %%
# Two-dimensional data set
np.random.seed(2000)
y = np.random.standard_normal((20, 2)).cumsum(axis=0)

# plot
plt.figure(figsize=(7, 4))
plt.plot(y, lw=1.5)
plt.plot(y, 'ro')
plt.grid(True)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A simple 2D plot')

# %%
# plot with a legend
plt.figure(figsize=(7, 4))
plt.plot(y[:, 0], lw=1.5, label='1st')
plt.plot(y[:, 1], lw=1.5, label='2nd')
plt.plot(y, 'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A simple 2D plot with legend')

# %%
# scalling problem example
y[:, 0] = y[:, 0] * 100
plt.figure(figsize=(7, 4))
plt.plot(y[:, 0], lw=1.5, label='1st')
plt.plot(y[:, 1], lw=1.5, label='2nd')
plt.plot(y, 'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('A simple 2D plot with legend')

# %%
# two y-axes plot
fig, ax1 = plt.subplots()
plt.plot(y[:, 0], 'b', lw=1.5, label='1st')
plt.plot(y[:, 0], 'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value 1st')
plt.title('A simple 2D plot with two y-axis')
ax2 = ax1.twinx()
plt.plot(y[:, 1], 'g', lw=1.5, label='2nd')
plt.plot(y[:, 1], 'ro')
plt.legend(loc=0)
plt.ylabel('value 2nd')

# %%
# two subplots
plt.figure(figsize=(7, 5))

plt.subplot(211)
plt.plot(y[:, 0], 'b', lw=1.5, label='1st')
plt.plot(y[:, 0], 'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.ylabel('value')
plt.title('A simple plot')

plt.subplot(212)
plt.plot(y[:, 1], 'g', lw=1.5, label='2nd')
plt.plot(y[:, 1], 'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')

# %%
# line plot with a bar plot
plt.figure(figsize=(9, 4))

plt.subplot(121)
plt.plot(y[:, 0], lw=1.5, label='1st')
plt.plot(y[:, 0], 'ro')
plt.grid(True)
plt.legend(loc=0)
plt.axis('tight')
plt.xlabel('index')
plt.ylabel('value')
plt.title('1st data set')

plt.subplot(122)
plt.bar(np.arange(len(y)), y[:, 1], width=0.5,
        color='g', label='2nd')
plt.grid(True)
plt.legend(loc=0)
plt.xlabel('index')
plt.ylabel('value')
plt.title('2nd data set')

# %%
# scatter plot
y = np.random.standard_normal((1000, 2))

plt.figure(figsize=(7, 5))
plt.plot(y[:, 0], y[:, 1], 'ro')
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter plot')

# %%
# scatter plot using the scatter function
plt.figure(figsize=(7, 5))
plt.scatter(y[:, 0], y[:, 1], marker='o')
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('Scatter plot')

# %%
# 3D scatter plot 
c = np.random.randint(0, 10, len(y))

plt.figure(figsize=(7, 5))
plt.scatter(y[:, 0], y[:, 1], c=c, marker='o')
plt.colorbar()
plt.grid(True)
plt.xlabel('1st')
plt.ylabel('2nd')
plt.title('3D scatter plot')

# %%
# histogram
plt.figure(figsize=(7, 4))
plt.hist(y, label=['1st', '2nd'], bins=25)
plt.grid(True)
plt.legend(loc=0)
plt.xlabel('index')
plt.ylabel('frequency')
plt.title('Histogram')

# %%
# stacked histogram
plt.figure(figsize=(7, 4))
plt.hist(y, label=['1st', '2nd'], color=['b', 'g'], stacked=True, bins=20)
plt.grid(True)
plt.legend(loc=0)
plt.xlabel('index')
plt.ylabel('frequency')
plt.title('Stacked histogram')

# %%
# boxplot
fig, ax = plt.subplots(figsize=(7, 4))
plt.boxplot(y)
plt.grid(True)
plt.setp(ax, xticklabels=['1st', '2nd'])
plt.xlabel('data set')
plt.ylabel('value')
plt.title('Boxplot')

# %%
# a more complete example with an integral
from matplotlib.patches import Polygon

def func(x):
    return 0.5 * np.exp(x) + 1

a, b = 0.5, 1.5 # integral limits
x = np.linspace(0, 2)
y = func(x)

fig, ax = plt.subplots(figsize=(7, 5))
plt.plot(x, y, 'b', linewidth=2)
plt.ylim(ymin=0)

# illustrate the integral
Ix = np.linspace(a, b)
Iy = func(Ix)
verts = [(a, 0)] + list(zip(Ix, Iy)) + [(b, 0)]
poly = Polygon(verts, facecolor='0.7', edgecolor='0.5')
ax.add_patch(poly)

plt.text(0.5 * (a + b), 1, r"$\int_a^b f(x)\mathrm{d}x$",
         horizontalalignment='center', fontsize=20)

plt.figtext(0.9, 0.075, '$x$')
plt.figtext(0.075, 0.9, '$f(x)$')

ax.set_xticks((a, b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([func(a), func(b)])
ax.set_yticklabels(('$f(a)$', '$f(b)$'))

plt.grid(True)

# %%
# financial plots
import matplotlib.finance as mpf

start = (2014, 5, 1)
end = (2014, 6, 30)
quotes = mpf.quotes_historical_yahoo_ohlc('^GDAXI', start, end)

# print first two quotes
quotes[:2]
# Out:
# [(735355.0,
#   9611.7900389999995,
#   9627.3798829999996,
#   9533.2998050000006,
#   9556.0195309999999,
#   88062300.0),
#  (735358.0,
#   9536.3798829999996,
#   9548.1699219999991,
#   9407.0898440000001,
#   9529.5,
#   61911600.0)]

# %%
# candlestick plot of the quotes
fig, ax = plt.subplots(figsize=(8, 5))
fig.subplots_adjust(bottom=0.2)
mpf.candlestick_ohlc(ax, quotes, width=0.6, colorup='b', colordown='r')
plt.grid(True)
ax.xaxis_date()
ax.autoscale_view()
plt.setp(plt.gca().get_xticklabels(), rotation=30)
# Out:
# [None, None, None, None, None, None, None, None]

# %%
# plot_day_summary function
fig, ax = plt.subplots(figsize=(8, 5))
mpf.plot_day_summary_ohlc(ax, quotes, colorup='b', colordown='r')
plt.grid(True)
ax.xaxis_date()
plt.title('DAX index')
plt.ylabel('index level')
plt.setp(plt.gca().get_xticklabels(), rotation=30)
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
# single plot with volume
quotes = np.array(mpf.quotes_historical_yahoo_ohlc('YHOO', start, end))

fig, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(8, 6))
mpf.candlestick_ohlc(ax1, quotes, width=0.6, colorup='b', colordown='r')
ax1.set_title('Yahoo Inc.')
ax1.set_ylabel('index level')
ax1.xaxis_date()
plt.bar(quotes[:, 0] - 0.25, quotes[:, 5], width=0.5)
ax2.set_ylabel('volume')
ax2.grid(True)
ax2.autoscale_view()
plt.setp(plt.gca().get_xticklabels(), rotation=30)
# Out:
# [None, None, None, None, None, None, None, None, None]

# %%
# 3D plotting
strike = np.linspace(50, 150, 24) # strike
ttm = np.linspace(0.5, 2.5, 24) # time-to-maturity
strike, ttm = np.meshgrid(strike, ttm) # make a 2D array from the 1D arrays strike and ttm

# %%
strike[:2]
# Out:
# array([[  50.        ,   54.34782609,   58.69565217,   63.04347826,
#           67.39130435,   71.73913043,   76.08695652,   80.43478261,
#           84.7826087 ,   89.13043478,   93.47826087,   97.82608696,
#          102.17391304,  106.52173913,  110.86956522,  115.2173913 ,
#          119.56521739,  123.91304348,  128.26086957,  132.60869565,
#          136.95652174,  141.30434783,  145.65217391,  150.        ],
#        [  50.        ,   54.34782609,   58.69565217,   63.04347826,
#           67.39130435,   71.73913043,   76.08695652,   80.43478261,
#           84.7826087 ,   89.13043478,   93.47826087,   97.82608696,
#          102.17391304,  106.52173913,  110.86956522,  115.2173913 ,
#          119.56521739,  123.91304348,  128.26086957,  132.60869565,
#          136.95652174,  141.30434783,  145.65217391,  150.        ]])

# %%
iv = (strike - 100) ** 2 / (100 * strike) / ttm # fake implied volatility

# %%
# plot the results
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(9, 6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(strike, ttm, iv, rstride=2, cstride=2,
                       cmap=plt.cm.coolwarm, linewidth=0.5, 
                       antialiased=True)
ax.set_xlabel('strike')
ax.set_ylabel('time-to-maturity')
ax.set_zlabel('implied volatility')
fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
# 3D scatter plot
fig = plt.figure(figsize=(8, 5))
ax = fig.add_subplot(111, projection='3d')
ax.view_init(30, 60)
ax.scatter(strike, ttm, iv, zdir='z', s=25,
           c='b', marker='^')
ax.set_xlabel('strike')
ax.set_ylabel('time-to-maturity')
ax.set_zlabel('implied volatility')
